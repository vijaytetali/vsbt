# %%
# Databricks notebook source
class Config():    
    def __init__(self):      
        self.base_dir_data = "/mnt/sbit-unmanaged-dev/data_zone"
        self.base_dir_checkpoint =  "/mnt/sbit-unmanaged-dev/chkpt_zone"
        self.db_name = "sbit_db"
        self.maxFilesPerTrigger = 1000
