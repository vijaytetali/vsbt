# %%
dbutils.fs.mount(source = "wasbs://sbit-managed-dev@vtstorage02.blob.core.windows.net/",mount_point = "/mnt/sbit-managed-dev",extra_configs = {'fs.azure.sas.sbit-managed-dev.vtstorage02.blob.core.windows.net':'sv=2024-11-04&ss=bfqt&srt=sco&sp=rwdlacupyx&se=2025-05-16T08:22:27Z&st=2025-05-13T00:22:27Z&spr=https&sig=l%2F%2BqkrU%2Btqka2tMhufaPYlObj45ObKKohxP8RbYr1CM%3D'})

# %%
dbutils.fs.mount(source = "wasbs://sbit-unmanaged-dev@vtstorage02.blob.core.windows.net/",mount_point = "/mnt/sbit-unmanaged-dev",extra_configs = {'fs.azure.sas.sbit-unmanaged-dev.vtstorage02.blob.core.windows.net':'sv=2024-11-04&ss=bfqt&srt=sco&sp=rwdlacupyx&se=2025-05-16T08:22:27Z&st=2025-05-13T00:22:27Z&spr=https&sig=l%2F%2BqkrU%2Btqka2tMhufaPYlObj45ObKKohxP8RbYr1CM%3D'})

# %%
dbutils.fs.mounts()
